# %%
# load data for plot loss function
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
import random
import time
import seaborn as sns
from scipy.cluster.hierarchy import dendrogram , linkage
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
data = pd.read_csv("SoftEpoches.csv")
data.head()
# Out:
#    Epoch      Loss
# 0      1  0.883573
# 1      2  0.973173
# 2      3  0.998762
# 3      4  0.979393
# 4      5  0.975869

# %%
data.plot()
# Out:
# <Axes: >

# %%
# Create the plot
plt.figure(figsize=(12, 6))
plt.plot(data['Epoch'], data['Loss'], marker='o', linestyle='-', color='b', markersize=4, alpha=0.7)
plt.title('Training Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()
